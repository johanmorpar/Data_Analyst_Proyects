# %% [markdown]
# <a href="https://colab.research.google.com/github/johanmorpar/Data_Analyst_Proyects/blob/main/Lappiz_Data_Mining_con_Terremotos_(USGS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🦖Data Mining con API - Terremotos (USGS)**

# %% [markdown]
# ##### **¿Qué es un API?**

# %% [markdown]
# Un **API (Application Programming Interface)** permite que diferentes aplicaciones se comuniquen entre sí.
#
# En Ciencia de Datos los APIs son fundamentales porque:
# - Permiten acceso automatizado a información
# - Devuelven datos en formato JSON
# - Son ampliamente utilizados en servicios web
#
# > API → JSON → Exploración → DataFrame  → Transformacion y limpieza → Calculos y Estadistica → Visualizacion.

# %% [markdown]
# ### **1 - Conectarnos al API**
#
# ----

# %% [markdown]
# > Endpoint:
# > https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson

# %%
import requests #petición HTTP para descargar los datos

# %%
# CARGA DE DATOS DESDE WEB
url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson'
print("Conectando y descargando datos desde el servidor gubernamental...")

response = requests.get(url)
response.raise_for_status()
print(f"  Estado HTTP: {response.status_code} (OK)")
# Out:
# Conectando y descargando datos desde el servidor gubernamental...
#   Estado HTTP: 200 (OK)

# %%
data = response.json()

# %% [markdown]
# ### **2 - Explorando (EDA) la estructura del JSON**
#
# ---
#
# Antes de convertir un archivo JSON complejo o anidado en una tabla de Pandas, es fundamental inspeccionar sus llaves principales, tipos de datos y niveles de anidación para mapear correctamente las variables.

# %%
# Ver las llaves principales del diccionario original
llaves_principales = list(data.keys())
print("1. Llaves principales encontradas en la raíz del JSON:")
print(llaves_principales)
# Out:
# 1. Llaves principales encontradas en la raíz del JSON:
# ['type', 'metadata', 'features', 'bbox']

# %%
# Validar el contenido de la sección 'metadata'
print("2. Resumen de Metadatos del Dataset:")
for llave, valor in data['metadata'].items():
    print(f"   - {llave}: {valor}")
# Out:
# 2. Resumen de Metadatos del Dataset:
#    - generated: 1784908866000
#    - url: https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson
#    - title: USGS All Earthquakes, Past Month
#    - status: 200
#    - api: 2.7.0
#    - count: 10577

# %%
# Tomamos el primer registro como muestra
muestra_registro = data['features'][0]

print("3. Diagnóstico de la estructura de un registro individual:")
print(f"Tipo de objeto: {type(muestra_registro)}")
print(f"Llaves internas del registro: {list(muestra_registro.keys())}")
print(f"Tipo de estructura en 'properties': {type(muestra_registro['properties'])}")
# Out:
# 3. Diagnóstico de la estructura de un registro individual:
# Tipo de objeto: <class 'dict'>
# Llaves internas del registro: ['type', 'properties', 'geometry', 'id']
# Tipo de estructura en 'properties': <class 'dict'>

# %% [markdown]
# cada registro de un sismo tiene su propia estructura interna (id, type, properties, geometry) toda la información analítica está compactada dentro de la variable properties.

# %%
# Extraemos las llaves internas de 'properties'
lista_propiedades = list(muestra_registro['properties'].keys())

print("=" * 50)
print(f" LISTA DE PROPIEDADES DISPONIBLES ({len(lista_propiedades)} en total):")
print("=" * 50)

for i, propiedad in enumerate(lista_propiedades, start=1):
    print(f"{i}. {propiedad}")
# Out:
# ==================================================
#  LISTA DE PROPIEDADES DISPONIBLES (26 en total):
# ==================================================
# 1. mag
# 2. place
# 3. time
# 4. updated
# 5. tz
# 6. url
# 7. detail
# 8. felt
# 9. cdi
# 10. mmi
# 11. alert
# 12. status
# 13. tsunami
# 14. sig
# 15. net
# 16. code
# 17. ids
# 18. sources
# 19. types
# 20. nst
# 21. dmin
# 22. rms
# 23. gap
# 24. magType
# 25. type
# 26. title

# %% [markdown]
# 📋 Glosario de Variables dentro de properties:
#
# **mag** (Magnitud): Es el tamaño o energía liberada por el sismo. Es una variable numérica continua fundamental para filtrar terremotos por su nivel de peligro (por ejemplo, mayores a 5.0).
#
# **place** (Lugar): Una descripción de texto de la ubicación geográfica aproximada del sismo (por ejemplo, "25km SV of Trinidad, Colorado"). Ideal para análisis de texto y agrupación por regiones.
#
# **time** (Tiempo): La fecha y hora exacta en la que ocurrió el sismo. Viene expresada en milisegundos en formato Epoch/Unix, por lo que requiere ser convertida con Pandas a formato fecha legible (datetime).
#
# **updated** (Actualizado): La marca de tiempo de la última vez que se modificó o recalculó el registro de ese sismo en los sistemas de la USGS.
#
# **tz** (Zona Horaria): El desfase de tiempo (offset) en minutos respecto al huso horario UTC del epicentro del sismo (campo que suele estar en desuso o nulo en eventos globales recientes).
#
# **url** (Enlace): Una dirección web directa a la página oficial de la USGS que contiene el reporte técnico e interactivo detallado de ese sismo en particular.
#
# **detail** (Detalle): La URL de la sub-API específica que contiene el JSON con la telemetría extendida de ese único evento (geometría, estaciones que lo reportaron, etc.).
#
# **felt** (Sentido): El número total de reportes públicos recibidos a través del sistema "¿Sintió un terremoto?" de la USGS. Es excelente para medir el impacto social de un sismo.
#
# **cdi** (Intensidad Comunitaria): La intensidad máxima reportada por la comunidad en la escala de Mercalli Modificada. Es una escala subjetiva basada en la percepción humana y daños visuales.
#
# **mmi** (Intensidad Instrumental): La intensidad máxima estimada mediante sensores e instrumentos técnicos automáticos en el epicentro.
#
# **alert** (Alerta): Una bandera de código de color basada en el sistema PAGER (Verde, Amarillo, Naranja, Rojo) que estima el nivel de fatalidades y daños económicos potenciales de inmediato.
#
# **status** (Estado): Indica si el sismo fue revisado por un sismólogo humano (reviewed) o si el registro fue procesado únicamente de manera automática por el sistema (automatic).
#
# **tsunami** (Tsunami): Una variable binaria (0 o 1). Indica con un 1 si el sismo generó de manera interna una alerta o evaluación de riesgo de tsunami en zonas costeras.
#
# **sig** (Significancia): Un número calculado por la USGS (de 0 a 1000) que determina qué tan importante o "noticioso" fue el evento, combinando magnitud, reportes de impacto (felt) y alertas de tsunami.
#
# **net** (Red): El identificador de la red sismológica que recolectó originalmente los datos y reportó el evento a la base de datos central de la USGS (por ejemplo, us, nc, ci).
#
# **code** (Código): El identificador único asignado por la red sismológica de origen para ese sismo específico.
#
# **ids** (Identificadores): Una cadena de texto que agrupa todos los códigos con los que diferentes redes mundiales asociaron a este mismo evento (útil para evitar duplicados si cruzas bases de datos).
#
# **sources** (Fuentes): Una lista de todas las redes o instituciones científicas que aportaron datos para calcular la localización y magnitud finales del sismo.
#
# **types** (Tipos de datos): Una lista de los tipos de productos de datos disponibles para este evento (como mapas de intensidad, archivos de falla, telemetría de ondas, etc.).
#
# **nst** (Número de Estaciones): La cantidad total de estaciones sismológicas que se utilizaron para determinar de manera precisa la localización del sismo.
#
# **dmin** (Distancia Mínima): La distancia horizontal desde el epicentro hasta la estación sismológica más cercana (expresada en grados dipolares). A menor distancia, mayor precisión en la profundidad.
#
# **rms** (Error RMS): El error cuadrático medio del tiempo de viaje de las ondas sísmicas (en segundos). Mide la calidad del ajuste matemático de la localización del sismo (valores cercanos a cero son ideales).
#
# **gap** (Brecha Azimutal): El espacio angular más grande sin cobertura de estaciones alrededor del epicentro (en grados). Si el gap es menor a 180°, la localización del sismo suele ser muy confiable.
#
# **magType** (Tipo de Magnitud): El método o escala científica utilizada para calcular la magnitud del sismo (por ejemplo, mw para Magnitud de Momento, o mb para Ondas de Cuerpo).
#
# **type** (Tipo de Evento): Clasifica la naturaleza del movimiento telúrico. Aunque la mayoría son earthquake (terremotos), también registra actividades como quarry blast (explosiones de canteras), ice quake (sismos de hielo) o explosion.

# %%
# Tomamos las propiedades del primer sismo
propiedades_muestra = data['features'][0]['properties']

print("=" * 70)
print(" EJEMPLO DE VALORES REALES EN LA PRIMERA FILA:")
print("=" * 70)

# Imprimimos la llave y su valor real
for llave, valor in propiedades_muestra.items():
    print(f"-> {llave.ljust(12)} : {valor}")
# Out:
# ======================================================================
#  EJEMPLO DE VALORES REALES EN LA PRIMERA FILA:
# ======================================================================
# -> mag          : 2.49
# -> place        : 22 km SSW of Hawthorne, Nevada
# -> time         : 1784908027761
# -> updated      : 1784908174086
# -> tz           : None
# -> url          : https://earthquake.usgs.gov/earthquakes/eventpage/nn00922278
# -> detail       : https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00922278.geojson
# -> felt         : None
# -> cdi          : None
# -> mmi          : None
# -> alert        : None
# -> status       : automatic
# -> tsunami      : 0
# -> sig          : 95
# -> net          : nn
# -> code         : 00922278
# -> ids          : ,nn00922278,
# -> sources      : ,nn,
# -> types        : ,origin,phase-data,
# -> nst          : 31
# -> dmin         : 0.124
# -> rms          : 0.3557
# -> gap          : 130
# -> magType      : ml
# -> type         : earthquake
# -> title        : M 2.5 - 22 km SSW of Hawthorne, Nevada

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1784908866000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson',
#   'title': 'USGS All Earthquakes, Past Month',
#   'status': 200,
#   'api': '2.7.0',
#   'count': 10577},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '22 km SSW of Hawthorne, Nevada',
#     'time': 1784908027761,
#     'updated': 1784908174086,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00922278',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00922278.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'nn',
#     'code': '00922278',
#     'ids': ',nn00922278,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.124,
#     'rms': 0.3557,
#     'gap': 130,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 22 km SSW of Hawthorne, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.7176, 38.339, 4.1577]},
#    'id': 'nn00922278'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '45 km WSW of Tatitlek, Alaska',
#     'time': 1784907781812,
#     'updated': 1784907850396,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026onzxpp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026onzxpp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': 'a2026onzxpp',
#     'ids': ',aka2026onzxpp,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.3,
#     'rms': 0.2,
#     'gap': 230,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 45 km WSW of Tatitlek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.41, 60.671, 10.5]},
#    'id': 'aka2026onzxpp'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.99,
#     'place': '15 km NE of New Idria, CA',
#     'time': 1784907671750,
#     'updated': 1784907768925,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75405032',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75405032.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 61,
#     'net': 'nc',
#     'code': '75405032',
#     'ids': ',nc75405032,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.09126,
#     'rms': 0.09,
#     'gap': 113,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 15 km NE of New Idria, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.552833557129, 36.5060005187988, 15.1000003814697]},
#    'id': 'nc75405032'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.51,
#     'place': '21 km ESE of Anza, CA',
#     'time': 1784907190410,
#     'updated': 1784907853010,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660682',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660682.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ci',
#     'code': '40660682',
#     'ids': ',ci40660682,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 74,
#     'dmin': 0.1182,
#     'rms': 0.2,
#     'gap': 25,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 21 km ESE of Anza, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.462166666667, 33.4778333333333, 10.82]},
#    'id': 'ci40660682'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.35,
#     'place': '14 km N of Morgan Hill, CA',
#     'time': 1784905135250,
#     'updated': 1784907442365,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75405012',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75405012.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 85,
#     'net': 'nc',
#     'code': '75405012',
#     'ids': ',nc75405012,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 59,
#     'dmin': 0.03314,
#     'rms': 0.07,
#     'gap': 42,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 14 km N of Morgan Hill, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.63166809082, 37.2568321228027, 5.05000019073486]},
#    'id': 'nc75405012'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '17 km NW of Midland, Texas',
#     'time': 1784904942416,
#     'updated': 1784908859494,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olpvkj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olpvkj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'tx',
#     'code': '2026olpvkj',
#     'ids': ',tx2026olpvkj,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 0,
#     'rms': 0.3,
#     'gap': 75,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 17 km NW of Midland, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-102.213, 32.105, 4.6625]},
#    'id': 'tx2026olpvkj'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.64,
#     'place': '5 km ENE of Johnson Lane, Nevada',
#     'time': 1784904926700,
#     'updated': 1784905069281,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00922276',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00922276.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 41,
#     'net': 'nn',
#     'code': '00922276',
#     'ids': ',nn00922276,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.185,
#     'rms': 0.1162,
#     'gap': 89,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 5 km ENE of Johnson Lane, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.6714, 39.0722, 5.0572]},
#    'id': 'nn00922276'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.61,
#     'place': '14 km N of Morgan Hill, CA',
#     'time': 1784904823400,
#     'updated': 1784908641503,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75405002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75405002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 40,
#     'net': 'nc',
#     'code': '75405002',
#     'ids': ',nc75405002,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.03311,
#     'rms': 0.06,
#     'gap': 68,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 14 km N of Morgan Hill, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.6318359375, 37.2556648254395, 5.15000009536743]},
#    'id': 'nc75405002'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '55 km NW of Toyah, Texas',
#     'time': 1784904601320,
#     'updated': 1784904814229,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olpqnf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olpqnf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'tx',
#     'code': '2026olpqnf',
#     'ids': ',tx2026olpqnf,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 0,
#     'rms': 0.4,
#     'gap': 65,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 55 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.225, 31.651, 6.3815]},
#    'id': 'tx2026olpqnf'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '20 km NNE of Skwentna, Alaska',
#     'time': 1784904568191,
#     'updated': 1784904665469,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026onyded',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026onyded.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': 'a2026onyded',
#     'ids': ',aka2026onyded,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.2,
#     'rms': 0.5,
#     'gap': 164,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 20 km NNE of Skwentna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.196, 62.148, 71.7]},
#    'id': 'aka2026onyded'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.22,
#     'place': '1 km S of Indios, Puerto Rico',
#     'time': 1784904410570,
#     'updated': 1784906316130,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525653',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525653.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 76,
#     'net': 'pr',
#     'code': '71525653',
#     'ids': ',pr71525653,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.05405,
#     'rms': 0.27,
#     'gap': 202,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 1 km S of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8225, 17.9766666666667, 11.91]},
#    'id': 'pr71525653'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '55 km NW of Toyah, Texas',
#     'time': 1784903873594,
#     'updated': 1784908580617,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olpfnv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olpfnv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'tx',
#     'code': '2026olpfnv',
#     'ids': ',tx2026olpfnv,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 65,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 55 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.221, 31.657, 6.6638]},
#    'id': 'tx2026olpfnv'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.07,
#     'place': '4 km S of Guánica, Puerto Rico',
#     'time': 1784903803350,
#     'updated': 1784904358900,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525633',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525633.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 66,
#     'net': 'pr',
#     'code': '71525633',
#     'ids': ',pr71525633,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.05363,
#     'rms': 0.09,
#     'gap': 218,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 4 km S of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.912, 17.9311666666667, 14.27]},
#    'id': 'pr71525633'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '23 km NW of Westbrook, Texas',
#     'time': 1784903514045,
#     'updated': 1784903752500,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olpawo',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olpawo.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'tx',
#     'code': '2026olpawo',
#     'ids': ',tx2026olpawo,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0,
#     'rms': 0.4,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 23 km NW of Westbrook, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.2, 32.5, 3.8144]},
#    'id': 'tx2026olpawo'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.51,
#     'place': '70 km NNE of Cruz Bay, U.S. Virgin Islands',
#     'time': 1784902410160,
#     'updated': 1784904790400,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525658',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525658.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 97,
#     'net': 'pr',
#     'code': '71525658',
#     'ids': ',pr71525658,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 3,
#     'dmin': 0.392,
#     'rms': 0.08,
#     'gap': 309,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 70 km NNE of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-64.4621666666667, 18.8801666666667, 6.08]},
#    'id': 'pr71525658'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.5,
#     'place': '31 km NW of Toyah, Texas',
#     'time': 1784901231961,
#     'updated': 1784901752412,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olntad',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olntad.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'tx',
#     'code': '2026olntad',
#     'ids': ',tx2026olntad,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0,
#     'rms': 0.3,
#     'gap': 126,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 31 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.023, 31.516, 4.2677]},
#    'id': 'tx2026olntad'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.68,
#     'place': '8 km SSE of Redlands, CA',
#     'time': 1784901146810,
#     'updated': 1784901350142,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660658',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660658.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'ci',
#     'code': '40660658',
#     'ids': ',ci40660658,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.06141,
#     'rms': 0.13,
#     'gap': 91,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 8 km SSE of Redlands, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.152666666667, 33.9838333333333, 9.25]},
#    'id': 'ci40660658'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '10 km SSW of Big Spring, Texas',
#     'time': 1784900889788,
#     'updated': 1784907403599,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olnpeg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olnpeg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'tx',
#     'code': '2026olnpeg',
#     'ids': ',tx2026olnpeg,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 33,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 43,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 10 km SSW of Big Spring, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.506, 32.163, 9.5459]},
#    'id': 'tx2026olnpeg'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.13,
#     'place': '5 km WNW of Banning, CA',
#     'time': 1784900711280,
#     'updated': 1784900912510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660650',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660650.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 20,
#     'net': 'ci',
#     'code': '40660650',
#     'ids': ',ci40660650,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 53,
#     'dmin': 0.1337,
#     'rms': 0.17,
#     'gap': 31,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 5 km WNW of Banning, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.925833333333, 33.944, 13.34]},
#    'id': 'ci40660650'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.08,
#     'place': '4 km NNE of Moreno Valley, CA',
#     'time': 1784899778040,
#     'updated': 1784899992099,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660642',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660642.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '40660642',
#     'ids': ',ci40660642,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 43,
#     'dmin': 0.04108,
#     'rms': 0.18,
#     'gap': 61,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 4 km NNE of Moreno Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.218833333333, 33.9623333333333, 12.53]},
#    'id': 'ci40660642'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '9 km SSW of Big Spring, Texas',
#     'time': 1784899646979,
#     'updated': 1784904787512,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olmxil',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olmxil.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'tx',
#     'code': '2026olmxil',
#     'ids': ',tx2026olmxil,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 51,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 9 km SSW of Big Spring, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.506, 32.165, 8.7646]},
#    'id': 'tx2026olmxil'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.01,
#     'place': '5 km SE of Aromas, CA',
#     'time': 1784899552950,
#     'updated': 1784900842637,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404972',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404972.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'nc',
#     'code': '75404972',
#     'ids': ',nc75404972,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.02669,
#     'rms': 0.16,
#     'gap': 64,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 5 km SE of Aromas, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.596832275391, 36.8580017089844, 5.1100001335144]},
#    'id': 'nc75404972'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.57,
#     'place': '8 km S of Brawley, CA',
#     'time': 1784899467200,
#     'updated': 1784899677877,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660634',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660634.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 38,
#     'net': 'ci',
#     'code': '40660634',
#     'ids': ',ci40660634,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 27,
#     'dmin': 0.038,
#     'rms': 0.23,
#     'gap': 72,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 8 km S of Brawley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.516166666667, 32.9078333333333, 9.15]},
#    'id': 'ci40660634'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.21,
#     'place': '6 km SSW of Pearblossom, CA',
#     'time': 1784898971080,
#     'updated': 1784899173336,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660618',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660618.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'ci',
#     'code': '40660618',
#     'ids': ',ci40660618,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.02643,
#     'rms': 0.17,
#     'gap': 31,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 6 km SSW of Pearblossom, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.9235, 34.4506666666667, 9.11]},
#    'id': 'ci40660618'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.4,
#     'place': '4 km SW of Ponce, Puerto Rico',
#     'time': 1784898968640,
#     'updated': 1784901469940,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525613',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525613.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 89,
#     'net': 'pr',
#     'code': '71525613',
#     'ids': ',pr71525613,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.07764,
#     'rms': 0.13,
#     'gap': 143,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 4 km SW of Ponce, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.6481666666667, 17.9758333333333, 12.08]},
#    'id': 'pr71525613'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '46 km NW of Toyah, Texas',
#     'time': 1784898908542,
#     'updated': 1784906891988,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olmmlq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olmmlq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'tx',
#     'code': '2026olmmlq',
#     'ids': ',tx2026olmmlq,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 38,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 70,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 46 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.185, 31.572, 6.7023]},
#    'id': 'tx2026olmmlq'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '54 km NW of Toyah, Texas',
#     'time': 1784898696200,
#     'updated': 1784906161020,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olmjpa',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olmjpa.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'tx',
#     'code': '2026olmjpa',
#     'ids': ',tx2026olmjpa,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 54 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.214, 31.654, 6.1383]},
#    'id': 'tx2026olmjpa'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '19 km N of Nikiski, Alaska',
#     'time': 1784897727389,
#     'updated': 1784897818748,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026onuihp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026onuihp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': 'a2026onuihp',
#     'ids': ',aka2026onuihp,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.1,
#     'rms': 0.6,
#     'gap': 76,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 19 km N of Nikiski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.28, 60.867, 75.8]},
#    'id': 'aka2026onuihp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '4 km SSW of Ponce, Puerto Rico',
#     'time': 1784897572210,
#     'updated': 1784899232780,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525603',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525603.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 101,
#     'net': 'pr',
#     'code': '71525603',
#     'ids': ',pr71525603,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.03949,
#     'rms': 0.16,
#     'gap': 141,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 4 km SSW of Ponce, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.6451666666667, 17.977, 12.31]},
#    'id': 'pr71525603'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.72,
#     'place': '2 km NW of The Geysers, CA',
#     'time': 1784897392140,
#     'updated': 1784899942535,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404957',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404957.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 46,
#     'net': 'nc',
#     'code': '75404957',
#     'ids': ',nc75404957,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 29,
#     'dmin': 0.01379,
#     'rms': 0.03,
#     'gap': 82,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 2 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.771835327148, 38.7874984741211, 3.16000008583069]},
#    'id': 'nc75404957'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '46 km NW of Toyah, Texas',
#     'time': 1784897200420,
#     'updated': 1784900085092,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026ollnux',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026ollnux.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'tx',
#     'code': '2026ollnux',
#     'ids': ',tx2026ollnux,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 36,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 70,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 46 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.181, 31.568, 7.7405]},
#    'id': 'tx2026ollnux'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.54,
#     'place': '20 km SSW of Hawthorne, Nevada',
#     'time': 1784897016338,
#     'updated': 1784897177152,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00922270',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00922270.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 99,
#     'net': 'nn',
#     'code': '00922270',
#     'ids': ',nn00922270,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.317,
#     'rms': 0.3496,
#     'gap': 79,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 20 km SSW of Hawthorne, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.7308, 38.3559, 14.1566]},
#    'id': 'nn00922270'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.16,
#     'place': '2 km SSW of Magas Arriba, Puerto Rico',
#     'time': 1784896651600,
#     'updated': 1784900426510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71525588',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71525588.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 72,
#     'net': 'pr',
#     'code': '71525588',
#     'ids': ',pr71525588,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.02647,
#     'rms': 0.11,
#     'gap': 184,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 2 km SSW of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7795, 17.996, 5.88]},
#    'id': 'pr71525588'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '194 km W of Abepura, Indonesia',
#     'time': 1784896022974,
#     'updated': 1784897093040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000t30v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000t30v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000t30v',
#     'ids': ',us7000t30v,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 60,
#     'dmin': 1.824,
#     'rms': 0.74,
#     'gap': 77,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 194 km W of Abepura, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [138.8797, -2.6055, 10]},
#    'id': 'us7000t30v'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '10 km N of Four Mile Road, Alaska',
#     'time': 1784895989916,
#     'updated': 1784896070440,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026ontjer',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026ontjer.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': 'a2026ontjer',
#     'ids': ',aka2026ontjer,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.1,
#     'rms': 0.8,
#     'gap': 66,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 10 km N of Four Mile Road, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.088, 64.696, 10]},
#    'id': 'aka2026ontjer'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '30 km SE of Skwentna, Alaska',
#     'time': 1784895473067,
#     'updated': 1784895567710,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026ontbsx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026ontbsx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'ak',
#     'code': 'a2026ontbsx',
#     'ids': ',aka2026ontbsx,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.3,
#     'rms': 0.8,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 30 km SE of Skwentna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.907, 61.836, 72.1]},
#    'id': 'aka2026ontbsx'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.4,
#     'place': '202 km W of Abepura, Indonesia',
#     'time': 1784895268267,
#     'updated': 1784903006609,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000t30r',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000t30r.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.155,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 449,
#     'net': 'us',
#     'code': '7000t30r',
#     'ids': ',us7000t30r,',
#     'sources': ',us,',
#     'types': ',ground-failure,losspager,origin,phase-data,shakemap,',
#     'nst': 88,
#     'dmin': 1.886,
#     'rms': 0.8,
#     'gap': 53,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.4 - 202 km W of Abepura, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [138.8159, -2.5572, 10]},
#    'id': 'us7000t30r'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.06,
#     'place': '23 km SSW of Hawthorne, Nevada',
#     'time': 1784895253858,
#     'updated': 1784895392410,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00922264',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00922264.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'nn',
#     'code': '00922264',
#     'ids': ',nn00922264,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.197,
#     'rms': 0.2823,
#     'gap': 134,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 23 km SSW of Hawthorne, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.7353, 38.3301, 6.4377]},
#    'id': 'nn00922264'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.96,
#     'place': '15 km WSW of Johannesburg, CA',
#     'time': 1784895119300,
#     'updated': 1784895326669,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660594',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660594.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'ci',
#     'code': '40660594',
#     'ids': ',ci40660594,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.07498,
#     'rms': 0.23,
#     'gap': 84,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 15 km WSW of Johannesburg, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.795666666667, 35.3303333333333, 8.32]},
#    'id': 'ci40660594'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.83,
#     'place': '7 km NW of The Geysers, CA',
#     'time': 1784894766260,
#     'updated': 1784896644164,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404937',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404937.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'nc',
#     'code': '75404937',
#     'ids': ',nc75404937,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 37,
#     'dmin': 0.00306,
#     'rms': 0.04,
#     'gap': 36,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 7 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.806167602539, 38.8231658935547, 2.22000002861023]},
#    'id': 'nc75404937'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '1 km E of Monte Giberto, Italy',
#     'time': 1784894712082,
#     'updated': 1784897215603,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000t30x',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000t30x.geojson',
#     'felt': 1,
#     'cdi': 0,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'us',
#     'code': '7000t30x',
#     'ids': ',us7000t30x,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.229,
#     'rms': 0.57,
#     'gap': 170,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 1 km E of Monte Giberto, Italy'},
#    'geometry': {'type': 'Point', 'coordinates': [13.6459, 43.0903, 10]},
#    'id': 'us7000t30x'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '15 km ESE of Pearsall, Texas',
#     'time': 1784892427099,
#     'updated': 1784895989659,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olixrn',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olixrn.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'tx',
#     'code': '2026olixrn',
#     'ids': ',tx2026olixrn,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.1,
#     'rms': 0.3,
#     'gap': 80,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 15 km ESE of Pearsall, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-98.958, 28.818, 8.6647]},
#    'id': 'tx2026olixrn'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.72,
#     'place': '8 km WNW of Cobb, CA',
#     'time': 1784892220290,
#     'updated': 1784892318202,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404932',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404932.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '75404932',
#     'ids': ',nc75404932,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.01211,
#     'rms': 0.01,
#     'gap': 56,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 8 km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.80916595459, 38.8354988098145, 2.26999998092651]},
#    'id': 'nc75404932'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.94,
#     'place': '13 km S of Fern Forest, Hawaii',
#     'time': 1784891833760,
#     'updated': 1784892042800,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv75007422',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv75007422.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 58,
#     'net': 'hv',
#     'code': '75007422',
#     'ids': ',hv75007422,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 0.04302,
#     'rms': 0.289999992,
#     'gap': 177,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 13 km S of Fern Forest, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.138168334961, 19.343334197998, 3.27999997138977]},
#    'id': 'hv75007422'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.01,
#     'place': '10 km SE of Winchester, CA',
#     'time': 1784891529940,
#     'updated': 1784891737558,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40660586',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40660586.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 16,
#     'net': 'ci',
#     'code': '40660586',
#     'ids': ',ci40660586,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 49,
#     'dmin': 0.01224,
#     'rms': 0.19,
#     'gap': 26,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 10 km SE of Winchester, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.016333333333, 33.6391666666667, 13.41]},
#    'id': 'ci40660586'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': '197 km W of Abepura, Indonesia',
#     'time': 1784891494234,
#     'updated': 1784892744040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000t309',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000t309.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 432,
#     'net': 'us',
#     'code': '7000t309',
#     'ids': ',us7000t309,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 72,
#     'dmin': 1.84,
#     'rms': 1.09,
#     'gap': 39,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.3 - 197 km W of Abepura, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [138.8612, -2.5436, 10]},
#    'id': 'us7000t309'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.71,
#     'place': '7 km WNW of Cobb, CA',
#     'time': 1784890899710,
#     'updated': 1784890997974,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404922',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404922.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '75404922',
#     'ids': ',nc75404922,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.009432,
#     'rms': 0.01,
#     'gap': 63,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 7 km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.801834106445, 38.8354988098145, 2.23000001907349]},
#    'id': 'nc75404922'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.32,
#     'place': '10 km SE of Cloverdale, CA',
#     'time': 1784890288650,
#     'updated': 1784892441712,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404917',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404917.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 27,
#     'net': 'nc',
#     'code': '75404917',
#     'ids': ',nc75404917,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 21,
#     'dmin': 0.06619,
#     'rms': 0.07,
#     'gap': 108,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 10 km SE of Cloverdale, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.928833007812, 38.7533340454102, 4.98999977111816]},
#    'id': 'nc75404917'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '7 km NW of The Geysers, CA',
#     'time': 1784890154320,
#     'updated': 1784890252642,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404912',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404912.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'nc',
#     'code': '75404912',
#     'ids': ',nc75404912,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.00924,
#     'rms': 0.02,
#     'gap': 52,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 7 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8193359375, 38.8139991760254, 2.75999999046326]},
#    'id': 'nc75404912'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.81,
#     'place': '13 km E of Naalehu, Hawaii',
#     'time': 1784889625930,
#     'updated': 1784889834150,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv75007402',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv75007402.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'hv',
#     'code': '75007402',
#     'ids': ',hv75007402,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.1056,
#     'rms': 0.25999999,
#     'gap': 251,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 13 km E of Naalehu, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.450500488281, 19.0498332977295, 36.9599990844727]},
#    'id': 'hv75007402'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '8 km SE of Gardendale, Texas',
#     'time': 1784889306209,
#     'updated': 1784906278000,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olhesk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olhesk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'tx',
#     'code': '2026olhesk',
#     'ids': ',tx2026olhesk,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 79,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 8 km SE of Gardendale, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-102.308, 31.969, 8.0811]},
#    'id': 'tx2026olhesk'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '7 km NW of The Geysers, CA',
#     'time': 1784889115390,
#     'updated': 1784891241585,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75404907',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75404907.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'nc',
#     'code': '75404907',
#     'ids': ',nc75404907,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.002247,
#     'rms': 0.02,
#     'gap': 40,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 7 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.809669494629, 38.8211669921875, 2.83999991416931]},
#    'id': 'nc75404907'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.93,
#     'place': '11 km SSE of Pāhala, Hawaii',
#     'time': 1784889047220,
#     'updated': 1784889264240,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv75007377',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv75007377.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 57,
#     'net': 'hv',
#     'code': '75007377',
#     'ids': ',hv75007377,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.05675,
#     'rms': 0.0799999982,
#     'gap': 192,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 11 km SSE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.442993164062, 19.1013336181641, 39.4900016784668]},
#    'id': 'hv75007377'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '55 km NW of Toyah, Texas',
#     'time': 1784889029382,
#     'updated': 1784904764519,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026olhawd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026olhawd.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'tx',
#     'code': '2026olhawd',
#     'ids': ',tx2026olhawd,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
# ...
#    'geometry': {'type': 'Point', 'coordinates': [-115.7429, 36.7106, 6.8962]},
#    'id': 'nn00922075'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.36,
#     'place': '83 km NNW of Karluk, Alaska',
#     'time': 1784618788110,
#     'updated': 1784668197910,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av94322943',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av94322943.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '94322943',
#     'ids': ',av94322943,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.05613,
#     'rms': 0.18,
#     'gap': 109,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.4 - 83 km NNW of Karluk, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.1035, 58.2345, 5.36]},
#    'id': 'av94322943'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.86,
#     'place': '12 km N of La Verne, CA',
#     'time': 1784618218520,
#     'updated': 1784640591281,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40658674',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40658674.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'ci',
#     'code': '40658674',
#     'ids': ',ci40658674,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 34,
#     'dmin': 0.04061,
#     'rms': 0.19,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 12 km N of La Verne, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.743166666667, 34.2088333333333, 13.66]},
#    'id': 'ci40658674'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.5,
#     'place': '18 km NNW of Stanton, Texas',
#     'time': 1784618210216,
#     'updated': 1784754705838,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026ofnlhi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026ofnlhi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'tx',
#     'code': '2026ofnlhi',
#     'ids': ',tx2026ofnlhi,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 54,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 18 km NNW of Stanton, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.883, 32.273, 5.7861]},
#    'id': 'tx2026ofnlhi'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.41,
#     'place': '3 km NW of The Geysers, CA',
#     'time': 1784617331570,
#     'updated': 1784619438990,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75402917',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75402917.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 31,
#     'net': 'nc',
#     'code': '75402917',
#     'ids': ',nc75402917,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 29,
#     'dmin': 0.009288,
#     'rms': 0.03,
#     'gap': 63,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 3 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.78116607666, 38.8008346557617, 3.25]},
#    'id': 'nc75402917'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.26,
#     'place': '17 km ESE of Anza, CA',
#     'time': 1784617291660,
#     'updated': 1784752613996,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40658666',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40658666.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'ci',
#     'code': '40658666',
#     'ids': ',ci40658666,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.08501,
#     'rms': 0.16,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 17 km ESE of Anza, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.500833333333, 33.502, 12.42]},
#    'id': 'ci40658666'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '17 km NNW of Stanton, Texas',
#     'time': 1784616203249,
#     'updated': 1784663372544,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026ofminc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026ofminc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'tx',
#     'code': '2026ofminc',
#     'ids': ',tx2026ofminc,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 53,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 24,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 17 km NNW of Stanton, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.878, 32.272, 8.4473]},
#    'id': 'tx2026ofminc'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '84 km SW of Puerto Madero, Mexico',
#     'time': 1784616195703,
#     'updated': 1784617169040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000t24u',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000t24u.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000t24u',
#     'ids': ',us7000t24u,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 49,
#     'dmin': 7.497,
#     'rms': 0.7,
#     'gap': 166,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 84 km SW of Puerto Madero, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-93.0019, 14.2069, 35]},
#    'id': 'us7000t24u'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '19 km NW of Stanton, Texas',
#     'time': 1784616112636,
#     'updated': 1784752541771,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026ofmfqf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026ofmfqf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'tx',
#     'code': '2026ofmfqf',
#     'ids': ',tx2026ofmfqf,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 19 km NW of Stanton, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.924, 32.257, 8.5205]},
#    'id': 'tx2026ofmfqf'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '18 km NNW of Stanton, Texas',
#     'time': 1784616063582,
#     'updated': 1784663949575,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026ofmgms',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026ofmgms.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'tx',
#     'code': '2026ofmgms',
#     'ids': ',tx2026ofmgms,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 48,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 24,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 18 km NNW of Stanton, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.879, 32.273, 7.8369]},
#    'id': 'tx2026ofmgms'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.28,
#     'place': '12 km NNE of Bray, Oklahoma',
#     'time': 1784615829130,
#     'updated': 1784725695396,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2026odtf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2026odtf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 25,
#     'net': 'ok',
#     'code': '2026odtf',
#     'ids': ',ok2026odtf,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 0.2114585046,
#     'rms': 0.31,
#     'gap': 184,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 12 km NNE of Bray, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.76033333, 34.741, 19]},
#    'id': 'ok2026odtf'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.01,
#     'place': '12 km NNE of Bray, Oklahoma',
#     'time': 1784615468380,
#     'updated': 1784725072103,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2026odta',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2026odta.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 16,
#     'net': 'ok',
#     'code': '2026odta',
#     'ids': ',ok2026odta,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.2213565623,
#     'rms': 0.25,
#     'gap': 159,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 12 km NNE of Bray, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.75, 34.7335, 5.54]},
#    'id': 'ok2026odta'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.71,
#     'place': '6 km WSW of Port Ludlow, Washington',
#     'time': 1784615427250,
#     'updated': 1784669349180,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw714055902',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uw714055902.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'uw',
#     'code': '714055902',
#     'ids': ',uw714055902,',
#     'sources': ',uw,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.09234,
#     'rms': 0.15,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 6 km WSW of Port Ludlow, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.757, 47.9003333333333, 16.4]},
#    'id': 'uw714055902'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.36,
#     'place': '9 km ENE of Pacolet Mills, South Carolina',
#     'time': 1784615132950,
#     'updated': 1784637310380,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60505983',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/se60505983.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'se',
#     'code': '60505983',
#     'ids': ',se60505983,',
#     'sources': ',se,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.1925,
#     'rms': 0.21,
#     'gap': 132,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 9 km ENE of Pacolet Mills, South Carolina'},
#    'geometry': {'type': 'Point', 'coordinates': [-81.643, 34.9525, 1.25]},
#    'id': 'se60505983'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '64 km NNW of Yakutat, Alaska',
#     'time': 1784614656791,
#     'updated': 1784839905293,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026ohszpf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026ohszpf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': 'a2026ohszpf',
#     'ids': ',aka2026ohszpf,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0,
#     'rms': 0.9,
#     'gap': 145,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 64 km NNW of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-140.206, 60.075, 6.1]},
#    'id': 'aka2026ohszpf'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.27,
#     'place': '15 km NE of Milford, Utah',
#     'time': 1784614518550,
#     'updated': 1784640742470,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu80145816',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu80145816.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 25,
#     'net': 'uu',
#     'code': '80145816',
#     'ids': ',uu80145816,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.01016,
#     'rms': 0.04,
#     'gap': 117,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 15 km NE of Milford, Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.910833333333, 38.5095, 2.79]},
#    'id': 'uu80145816'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '229 km ESE of Attu Station, Alaska',
#     'time': 1784614274908,
#     'updated': 1784839868832,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/aka2026ohsuhn',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/aka2026ohsuhn.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1.689,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'ak',
#     'code': 'a2026ohsuhn',
#     'ids': ',aka2026ohsuhn,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': 24,
#     'dmin': 1.4,
#     'rms': 0.8,
#     'gap': 194,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 229 km ESE of Attu Station, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [176.257, 51.986, 1]},
#    'id': 'aka2026ohsuhn'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '29 km NW of Toyah, Texas',
#     'time': 1784614263328,
#     'updated': 1784665963220,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2026oflgow',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2026oflgow.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'tx',
#     'code': '2026oflgow',
#     'ids': ',tx2026oflgow,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 66,
#     'dmin': 0.1,
#     'rms': 0.3,
#     'gap': 62,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 29 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.007, 31.505, 8.2404]},
#    'id': 'tx2026oflgow'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.61,
#     'place': '14 km ENE of Ridgecrest, CA',
#     'time': 1784614240240,
#     'updated': 1784649530637,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40658658',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40658658.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '40658658',
#     'ids': ',ci40658658,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.09453,
#     'rms': 0.13,
#     'gap': 75,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 14 km ENE of Ridgecrest, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.538833333333, 35.6773333333333, 2.54]},
#    'id': 'ci40658658'},
#   ...],
#  'bbox': [-179.9785, -62.1125, -3.33, 179.9991, 73.7141, 676.469]}

# %% [markdown]
# ### **3 - Estructurando la información del dataframe**
#
# ---

# %%
import pandas as pd #crear y manipular el DataFrame

# %% [markdown]
# **3.1 Primero elegimos un solo terremoto (por ejemplo, el primer registro) y extraemos sus variables principales desde la llave 'properties'.**

# %%
# 1. Tomamos el primer registro de la lista de sismos como muestra
sismo_muestra = data['features'][0]['properties']

# 2. Extraemos las variables individuales que queramos analizar
place = sismo_muestra['place']
mag = sismo_muestra['mag']
type_event = sismo_muestra['type']
tsunami = sismo_muestra['tsunami']

# 3. Empaquetamos las variables en un diccionario de listas
sismo_dict = {
    'place': [place],
    'mag': [mag],
    'type': [type_event],
    'tsunami': [tsunami]
}

# 4. Creamos el DataFrame
df_muestra = pd.DataFrame(sismo_dict)
df_muestra
# Out:
#                             place   mag        type  tsunami
# 0  22 km SSW of Hawthorne, Nevada  2.49  earthquake        0

# %% [markdown]
# **3.2 crear el DataFrame con los +10,000 registros completos**

# %%
# Convierte toda la lista de miles de terremotos en una tabla completa
lista_propiedades = [sismo['properties'] for sismo in data['features']]

# DataFrame con todos los registros y todas las columnas
df_sismos = pd.DataFrame(lista_propiedades)

# Muestra de las columnas principales
df_sismos[['place', 'mag', 'type', 'tsunami']].head(5)
# Out:
#                             place   mag        type  tsunami
# 0  22 km SSW of Hawthorne, Nevada  2.49  earthquake        0
# 1   45 km WSW of Tatitlek, Alaska  1.60  earthquake        0
# 2       15 km NE of New Idria, CA  1.99  earthquake        0
# 3           21 km ESE of Anza, CA  1.51  earthquake        0
# 4      14 km N of Morgan Hill, CA  2.35  earthquake        0

# %%
df_sismos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10577 entries, 0 to 10576
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mag      10576 non-null  float64
#  1   place    10577 non-null  object
#  2   time     10577 non-null  int64
#  3   updated  10577 non-null  int64
#  4   tz       0 non-null      object
#  5   url      10577 non-null  object
#  6   detail   10577 non-null  object
#  7   felt     496 non-null    float64
#  8   cdi      496 non-null    float64
#  9   mmi      192 non-null    float64
#  10  alert    76 non-null     object
#  11  status   10577 non-null  object
#  12  tsunami  10577 non-null  int64
#  13  sig      10577 non-null  int64
#  14  net      10577 non-null  object
#  15  code     10577 non-null  object
#  16  ids      10577 non-null  object
#  17  sources  10577 non-null  object
#  18  types    10577 non-null  object
#  19  nst      10566 non-null  float64
#  20  dmin     10559 non-null  float64
#  21  rms      10565 non-null  float64
#  22  gap      10565 non-null  float64
#  23  magType  10576 non-null  object
#  24  type     10577 non-null  object
#  25  title    10577 non-null  object
# dtypes: float64(8), int64(4), object(14)
# memory usage: 2.1+ MB

# %% [markdown]
# **3.3 Clasificación de variables cuantitativas y cualitativas**

# %%
import numpy as np #Calculos y manejo de valores nulos

# %%
#Detectar columnas que contienen listas (cols_lista)
cols_lista = [
    col for col in df_sismos.columns
    if df_sismos[col].apply(lambda x: isinstance(x, list)).any()
]

# %% [markdown]
# **cols_lista** = [ ... ]
# : Crea una nueva variable llamada cols_lista mediante una comprensión de listas.
#
# **col for col in df_sismos.columns**
# : Es un bucle que recorre, una por una, todas las columnas existentes en el DataFrame df_sismos. En cada vuelta, la variable col toma el nombre de una columna (por ejemplo: 'mag', 'place', 'sources', etc.).
#
# **if df_sismos[col].apply(lambda x: isinstance(x, list)).any()**
# : Es la condición para incluir la columna en la lista final. Se desglosa así de adentro hacia afuera:

# %%
#Filtrar variables cuantitativas (cuantitativas)

cuantitativas = df_sismos.select_dtypes(include=[np.number]).columns.tolist()

# %% [markdown]
# **df_sismos.select_dtypes(include=[np.number])**
# : Filtra la tabla entera y selecciona únicamente las columnas cuyo tipo de dato sea numérico (tanto enteros int como decimales float).
#
# **.columns**
# : Extrae solo los nombres de las columnas resultantes de ese filtro (en lugar de traer todos los datos almacenados en ellas).
#
# **.tolist()**
# : Convierte ese objeto de nombres de columnas de Pandas a una lista nativa de Python.

# %%
#Filtrar variables cualitativas (cualitativas)
cualitativas = [
    col for col in df_sismos.select_dtypes(include=["object", "bool"]).columns
    if col not in cols_lista
]

# %% [markdown]
# **cualitativas = [ ... ]**
# : Abre una segunda comprensión de listas para almacenar las columnas categóricas o de texto.
#
# **col for col in df_sismos.select_dtypes(include=["object", "bool"]).columns**
# : Busca y recorre únicamente las columnas cuyos tipos de datos sean texto/objetos ("object") o verdaderos/falsos ("bool").
#
# **if col not in cols_lista**
# : Es un filtro de exclusión clave: verifica que la columna de texto no haya sido clasificada previamente como una lista en el paso 1. Esto evita que columnas multivaluadas (como sources) se dupliquen por error dentro de las variables cualitativas simples.

# %%
#RESULTADOS DE VARIABLES

print(f"\n Variables CUANTITATIVAS (numéricas): {len(cuantitativas)}")
for v in cuantitativas:
    print(f"   • {v:20s} -> {df_sismos[v].dtype}")

print(f"\n Variables CUALITATIVAS (categóricas/texto): {len(cualitativas)}")
for v in cualitativas:
    print(f"   • {v:20s} -> {df_sismos[v].dtype}")

print(f"\n Variables tipo LISTA (multivaluadas): {len(cols_lista)}")
for v in cols_lista:
    print(f"   • {v:20s} -> lista de valores")
# Out:
#  Variables CUANTITATIVAS (numéricas): 12
#    • mag                  -> float64
#    • time                 -> int64
#    • updated              -> int64
#    • felt                 -> float64
#    • cdi                  -> float64
#    • mmi                  -> float64
#    • tsunami              -> int64
#    • sig                  -> int64
#    • nst                  -> float64
#    • dmin                 -> float64
#    • rms                  -> float64
#    • gap                  -> float64
#
#  Variables CUALITATIVAS (categóricas/texto): 14
#    • place                -> object
#    • tz                   -> object
#    • url                  -> object
#    • detail               -> object
#    • alert                -> object
#    • status               -> object
#    • net                  -> object
#    • code                 -> object
#    • ids                  -> object
#    • sources              -> object
#    • types                -> object
#    • magType              -> object
#    • type                 -> object
#    • title                -> object
#
#  Variables tipo LISTA (multivaluadas): 0

# %% [markdown]
# ### **4. Preprocesamiento: Limpieza de datos & Feature Engineering**
# ----

# %% [markdown]
# **4.1 Copia de Respaldo y Selección de Columnas Utiles**
#
# En esta primera etapa creamos una copia del DataFrame original para no perder los datos crudos y eliminamos las columnas que son redundantes o técnicas que no aportan al análisis.

# %% [markdown]
# Se seleccionaron 18 columnas estratégicas que responden a las dimensiones de evento (mag, type), espacio (place), tiempo (time) e impacto/calidad (felt, alert, gap). Este filtro elimina variables técnicas y enlaces innecesarios para centrar el análisis en la energía liberada, la ubicación, el riesgo social y la precisión de los datos. Así se optimiza el uso de memoria y se garantiza una base limpia para el Feature Engineering y el cálculo de estadísticas.

# %%
# Crear una copia de seguridad para trabajar sobre ella
df_limpio = df_sismos.copy()

# Definir las columnas útiles para nuestro análisis
columnas_interes = [
    'mag', 'place', 'time', 'updated', 'felt', 'cdi', 'mmi',
    'alert', 'status', 'tsunami', 'sig', 'net', 'nst', 'dmin',
    'rms', 'gap', 'magType', 'type'
]

# Filtrar el DataFrame
df_limpio = df_limpio[columnas_interes]

print(f" Copia creada. Dimensiones actuales: {df_limpio.shape[0]} filas y {df_limpio.shape[1]} columnas.")
# Out:
#  Copia creada. Dimensiones actuales: 10577 filas y 18 columnas.

# %% [markdown]
# **4.2 Conversión de Fechas (Epoch a Datetime)**

# %%
# Convertir de milisegundos a formato Datetime con Pandas
df_limpio['fecha_hora'] = pd.to_datetime(df_limpio['time'], unit='ms')
df_limpio['fecha_actualizacion'] = pd.to_datetime(df_limpio['updated'], unit='ms')

# Eliminar las columnas originales en milisegundos para no duplicar datos
df_limpio.drop(columns=['time', 'updated'], inplace=True)

print(" Fechas convertidas con éxito.")
print(df_limpio[['fecha_hora', 'fecha_actualizacion']].head(5))
# Out:
#  Fechas convertidas con éxito.
#                fecha_hora     fecha_actualizacion
# 0 2026-07-24 15:47:07.761 2026-07-24 15:49:34.086
# 1 2026-07-24 15:43:01.812 2026-07-24 15:44:10.396
# 2 2026-07-24 15:41:11.750 2026-07-24 15:42:48.925
# 3 2026-07-24 15:33:10.410 2026-07-24 15:44:13.010
# 4 2026-07-24 14:58:55.250 2026-07-24 15:37:22.365

# %% [markdown]
# **4.3 Feature Engineering Geográfico (Limpieza de place)**

# %%
# Función para extraer la región o país, despues de la coma ','.
def extraer_region(texto):
    if isinstance(texto, str) and ',' in texto:
        return texto.split(',')[-1].strip()
    elif isinstance(texto, str):
        return texto.strip()
    return 'Desconocido'

# Crear la columna de Región / Estado
df_limpio['region'] = df_limpio['place'].apply(extraer_region)

# Estandarizar a mayúsculas para evitar duplicados por formato
df_limpio['region'] = df_limpio['region'].str.title()

print(" Extracción geográfica completada.")
print(df_limpio[['place', 'region']].head(10))
# Out:
#  Extracción geográfica completada.
#                               place  region
# 0    22 km SSW of Hawthorne, Nevada  Nevada
# 1     45 km WSW of Tatitlek, Alaska  Alaska
# 2         15 km NE of New Idria, CA      Ca
# 3             21 km ESE of Anza, CA      Ca
# 4        14 km N of Morgan Hill, CA      Ca
# 5        17 km NW of Midland, Texas   Texas
# 6  5 km ENE of Johnson Lane, Nevada  Nevada
# 7        14 km N of Morgan Hill, CA      Ca
# 8          55 km NW of Toyah, Texas   Texas
# 9     20 km NNE of Skwentna, Alaska  Alaska

# %% [markdown]
# **4.4 Tratamiento Estratégico de Valores Nulos (NaN)**

# %%
# Variable'felt' (reportes de personas): Si es NaN, significa que 0 personas lo reportaron
df_limpio['felt'] = df_limpio['felt'].fillna(0).astype(int)

# Variable 'tsunami': Si es NaN, asumimos que no hubo alerta (0)
df_limpio['tsunami'] = df_limpio['tsunami'].fillna(0).astype(int)

# Variable 'alert': Si es NaN, asignamos la categoría 'sin_alerta'
df_limpio['alert'] = df_limpio['alert'].fillna('sin_alerta')

# Variable 'mag' (magnitud): Si hay registros sin magnitud, los eliminamos (no sirven para el análisis)
df_limpio.dropna(subset=['mag'], inplace=True)

print(" Valores nulos tratados correctamente.")
# Out:
#  Valores nulos tratados correctamente.

# %%
#Comprobar que ya NO hay valores nulos
print("--- Cantidad de valores nulos restantes por columna ---")
print(df_limpio.isnull().sum())
# Out:
# --- Cantidad de valores nulos restantes por columna ---
# mag                        0
# place                      0
# felt                       0
# cdi                    10080
# mmi                    10384
# alert                      0
# status                     0
# tsunami                    0
# sig                        0
# net                        0
# nst                       11
# dmin                      18
# rms                       12
# gap                       12
# magType                    0
# type                       0
# fecha_hora                 0
# fecha_actualizacion        0
# region                     0
# dtype: int64

# %%
#Diagnóstico de los datos nulos restantes: cdi y mmi (~10,000 nulos) y tambien: nst, dmin, rms, gap (entre 11 y 17 nulos)

# 1. Imputar intensidades (cdi y mmi) con 0
df_limpio['cdi'] = df_limpio['cdi'].fillna(0)
df_limpio['mmi'] = df_limpio['mmi'].fillna(0)

# 2. Imputar nst (número de estaciones) con 0 y convertir a entero
df_limpio['nst'] = df_limpio['nst'].fillna(0).astype(int)

# 3. Imputar dmin, rms y gap con la mediana de cada columna
for col in ['dmin', 'rms', 'gap']:
    mediana = df_limpio[col].median()
    df_limpio[col] = df_limpio[col].fillna(mediana)

# %%
# Verificar nuevamente los nulos
print("--- Confirmación final de nulos ---")
print(df_limpio.isnull().sum(), "nulos totales en la tabla.")
# Out:
# --- Confirmación final de nulos ---
# mag                    0
# place                  0
# felt                   0
# cdi                    0
# mmi                    0
# alert                  0
# status                 0
# tsunami                0
# sig                    0
# net                    0
# nst                    0
# dmin                   0
# rms                    0
# gap                    0
# magType                0
# type                   0
# fecha_hora             0
# fecha_actualizacion    0
# region                 0
# dtype: int64 nulos totales en la tabla.

# %% [markdown]
# **4.5 Creación de Variables Categóricas Útiles**

# %% [markdown]
# Agrupamos las magnitudes continuas en rangos discretos según la escala sismológica para facilitar la generación de informes y gráficos.

# %%
# Definir límites y etiquetas para la escala de magnitudes
limites_mag = [-np.inf, 2.5, 4.5, 6.0, 7.0, np.inf] # En NumPy: límite inferior (-np.inf) y limite superior (np.inf)
etiquetas_mag = ['Micro (<2.5)', 'Menor (2.5-4.4)', 'Moderado (4.5-5.9)', 'Fuerte (6.0-6.9)', 'Mayor (>=7.0)']

# Crear la nueva variable categorizada
df_limpio['categoria_magnitud'] = pd.cut( #pd.cut(...) función para segmentar y clasificar valores numéricos en intervalos discretos
    df_limpio['mag'],
    bins=limites_mag, #bins: define las fronteras de los intervalos
    labels=etiquetas_mag #etiquetas: nombres que recibirá cada intervalo
)

# Extraer hora y día de la semana para análisis temporal
df_limpio['hora_dia'] = df_limpio['fecha_hora'].dt.hour
df_limpio['dia_semana'] = df_limpio['fecha_hora'].dt.day_name()

print(" Variables de Feature Engineering agregadas.")
# Out:
#  Variables de Feature Engineering agregadas.

# %% [markdown]
# **4.6 Verificación Final del Dataset Limpio**

# %%
print("=" * 80)
print(" RESUMEN DEL DATAFRAME PROCESADO Y LIMPIO")
print("=" * 80)
print(f"• Registros totales: {len(df_limpio):,}")
print(f"• Total de columnas: {df_limpio.shape[1]}")
print(f"• Valores nulos restantes en 'mag': {df_limpio['mag'].isnull().sum()}")
print("\n--- Vista previa de las columnas clave ---")
print(df_limpio[['fecha_hora', 'region', 'mag', 'categoria_magnitud', 'felt', 'alert']].head(5))
# Out:
# ================================================================================
#  RESUMEN DEL DATAFRAME PROCESADO Y LIMPIO
# ================================================================================
# • Registros totales: 10,576
# • Total de columnas: 22
# • Valores nulos restantes en 'mag': 0
#
# --- Vista previa de las columnas clave ---
#                fecha_hora  region   mag categoria_magnitud  felt       alert
# 0 2026-07-24 15:47:07.761  Nevada  2.49       Micro (<2.5)     0  sin_alerta
# 1 2026-07-24 15:43:01.812  Alaska  1.60       Micro (<2.5)     0  sin_alerta
# 2 2026-07-24 15:41:11.750      Ca  1.99       Micro (<2.5)     0  sin_alerta
# 3 2026-07-24 15:33:10.410      Ca  1.51       Micro (<2.5)     0  sin_alerta
# 4 2026-07-24 14:58:55.250      Ca  2.35       Micro (<2.5)     0  sin_alerta

# %% [markdown]
# ### **5. Procesamiento: Estadisticas y Calculos**
#
# ---

# %% [markdown]
# **5.1 Resumen Estadístico Global** (Variables Continuas: mag, felt, cdi, mmi, nst, dmin, rms, gap)
#
# Calculamos la media, mediana, desviación estándar, IQR, mínimos y máximos de las variables numéricas clave:

# %%
# Columnas numéricas continuas principales
cols_continuas = ['mag', 'felt', 'cdi', 'mmi', 'nst', 'dmin', 'rms', 'gap']

# Construir tabla de estadísticas descriptivas completas
resumen_continuas = pd.DataFrame({
    'Media': df_limpio[cols_continuas].mean(),
    'Mediana (Q2)': df_limpio[cols_continuas].median(),
    'Desv. Estándar': df_limpio[cols_continuas].std(),
    'Q1 (25%)': df_limpio[cols_continuas].quantile(0.25),
    'Q3 (75%)': df_limpio[cols_continuas].quantile(0.75),
    'IQR': df_limpio[cols_continuas].quantile(0.75) - df_limpio[cols_continuas].quantile(0.25),
    'Mínimo': df_limpio[cols_continuas].min(),
    'Máximo': df_limpio[cols_continuas].max(),
    'Asimetría (Skew)': df_limpio[cols_continuas].skew()
})

print("="*80)
print(" RESUMEN NUMÉRICO GLOBAL (VARIABLES CONTINUAS)")
print("="*80)
display(resumen_continuas.round(2))
# Out:
# ================================================================================
#  RESUMEN NUMÉRICO GLOBAL (VARIABLES CONTINUAS)
# ================================================================================
#        Media  Mediana (Q2)  Desv. Estándar  Q1 (25%)  Q3 (75%)    IQR  Mínimo  \
# mag     1.67          1.50            1.24      0.85      2.10   1.25   -1.31
# felt    1.27          0.00           29.93      0.00      0.00   0.00    0.00
# cdi     0.10          0.00            0.55      0.00      0.00   0.00    0.00
# mmi     0.06          0.00            0.46      0.00      0.00   0.00    0.00
# nst    25.59         19.00           22.61     11.00     33.00  22.00    0.00
# dmin    0.55          0.08            1.92      0.03      0.30   0.27    0.00
# rms     0.30          0.20            0.28      0.10      0.48   0.38    0.00
# gap   115.89         91.00           70.32     64.00    155.00  91.00   12.00
#
#        Máximo  Asimetría (Skew)
# mag      7.50              1.07
# felt  2028.00             43.80
# cdi      8.90              6.28
# mmi      8.69              9.56
# nst    299.00              3.22
# dmin    42.24              9.70
# rms      2.60              1.34
# gap    352.00              1.05

# %% [markdown]
#  **Medidas de Tendencia Central y Posición**
#
#  **Mediana (Q2 / 50%)**: Es el valor que está justo en el centro del dataset. Representa al sismo "típico" y es la medida más confiable porque no se deja alterar por valores extremos.
#
#  **Media (Promedio)**: La suma de todos los valores dividida entre el total. Si difiere mucho de la mediana, indica la presencia de datos muy altos o muy bajos.
#
#  **Q1 (25%) y Q3 (75%)**: El Q1 indica que el 25% de los sismos tienen un valor igual o menor a este límite. El Q3 marca el punto donde el 75% de los datos queda por debajo.
#
#  **IQR (Rango Intercuartílico)**: Es la diferencia entre Q3 y Q1 ($IQR = Q3 - Q1$). Mide la dispersión del 50% central de tus datos; mientras más pequeño, más concentrados están los datos.
#
# **Medidas de Dispersión y Forma**
#
# **Mínimo y Máximo**: Determinan los valores extremos (el sismo de menor y mayor magnitud/impacto registrado).
#
# **Desviación Estándar**: Mide qué tanto se alejan los datos en promedio respecto a la media. Una desviación baja indica datos muy agrupados.
#
# **Asimetría (Skewness)**: Indica hacia dónde se inclinan los datos. Un valor positivo alto significa que la gran mayoría de los eventos son pequeños y solo unos pocos son muy grandes (cola a la derecha).
#
# **Frecuencias y Métricas Categóricas**
#
# **Moda**: El valor o categoría que se repite con mayor frecuencia en la columna (ej. la alerta más común o el tipo de evento predominante).

# %% [markdown]
# #### **5.2 Resumen Categórico y Frecuencias (Variables Discretas: 'type', 'categoria_magnitud', 'alert', 'tsunami', 'net')**
#
# Analizamos las frecuencias absolutas, relativas (%) y modas de las variables categóricas:

# %%
cols_categoricas = ['type', 'categoria_magnitud', 'alert', 'tsunami', 'net']

print("="*80)
print("RESUMEN CATEGÓRICO Y FRECUENCIAS")
print("="*80)

for col in cols_categoricas: #(ciclo) que va a recorrer, una por una, las variables definidas en la lista cols_categoricas
    print(f"\n--- Variable: '{col}' ---") #Imprime un subtítulo que indica qué variable se está analizando en ese momento
    df_freq = pd.DataFrame({ #DataFrame "df_freq" para almacenar y estructurar la tabla de frecuencias de la variable actual.
        'Conteo Absoluto': df_limpio[col].value_counts(), #Cuenta las veces de la categoría en la columna col mediante .value_counts() y asigna esos valores a la columna 'Conteo Absoluto'.
        'Porcentaje (%)': (df_limpio[col].value_counts(normalize=True) * 100).round(2) #value_counts(normalize=True) calcula la frecuencia relativa de cada categoría (valores decimales entre 0 y 1) y redondea.
    })
    display(df_freq)
    print(f"Moda de '{col}': {df_limpio[col].mode()[0]}") #obtiene la moda (el valor o categoría más frecuente de esa columna) y [0] muestra el primer valor.
# Out:
# ================================================================================
# RESUMEN CATEGÓRICO Y FRECUENCIAS
# ================================================================================
#
# --- Variable: 'type' ---
#                         Conteo Absoluto  Porcentaje (%)
# type
# earthquake                        10366           98.01
# quarry blast                        116            1.10
# explosion                            86            0.81
# ice quake                             7            0.07
# experimental explosion                1            0.01
# Moda de 'type': earthquake
#
# --- Variable: 'categoria_magnitud' ---
#                     Conteo Absoluto  Porcentaje (%)
# categoria_magnitud
# Micro (<2.5)                   8774           82.96
# Menor (2.5-4.4)                1355           12.81
# Moderado (4.5-5.9)              434            4.10
# Fuerte (6.0-6.9)                 10            0.09
# Mayor (>=7.0)                     3            0.03
# Moda de 'categoria_magnitud': Micro (<2.5)
#
# --- Variable: 'alert' ---
#             Conteo Absoluto  Porcentaje (%)
# alert
# sin_alerta            10500           99.28
# green                    70            0.66
# yellow                    4            0.04
# red                       2            0.02
# Moda de 'alert': sin_alerta
#
# --- Variable: 'tsunami' ---
#          Conteo Absoluto  Porcentaje (%)
# tsunami
# 0                  10576           100.0
# Moda de 'tsunami': 0
#
# --- Variable: 'net' ---
#      Conteo Absoluto  Porcentaje (%)
# net
# ak              2071           19.58
# nc              1844           17.44
# ci              1639           15.50
# us              1221           11.55
# tx               996            9.42
# av               913            8.63
# hv               431            4.08
# uu               366            3.46
# uw               352            3.33
# pr               289            2.73
# ok               171            1.62
# nn               133            1.26
# mb               107            1.01
# nm                29            0.27
# se                14            0.13
# Moda de 'net': ak

# %% [markdown]
# ####**5.3 Agregaciones por Regionalización (Top 10 Regiones)**
#
# Agrupamos por region para identificar las zonas con mayor actividad y su nivel de severidad:

# %%
# Filtrar top 10 regiones con mayor volumen
top_10_regiones = df_limpio['region'].value_counts().head(10).index

geo_stats = df_limpio[df_limpio['region'].isin(top_10_regiones)].groupby('region').agg(
    Total_Sismos=('mag', 'count'),
    Mag_Mediana=('mag', 'median'),
    Mag_Maxima=('mag', 'max'),
    Promedio_Reportes_Felt=('felt', 'mean'),
    Alertas_Tsunami=('tsunami', 'sum')
).sort_values(by='Total_Sismos', ascending=False)

print("="*80)
print(" 🌍 3. ESTADÍSTICAS AGREGADAS POR TOP 10 REGIONES")
print("="*80)
display(geo_stats.round(2))
# Out:
# ================================================================================
#  🌍 3. ESTADÍSTICAS AGREGADAS POR TOP 10 REGIONES
# ================================================================================
#              Total_Sismos  Mag_Mediana  Mag_Maxima  Promedio_Reportes_Felt  \
# region
# Ca                   3449         1.02        4.42                    1.03
# Alaska               3219         1.80        5.40                    0.80
# Texas                 778         1.40        5.00                    0.64
# Hawaii                432         1.81        4.53                    1.28
# Washington            288         0.94        3.80                    7.50
# Utah                  268         1.11        2.62                    0.07
# Puerto Rico           225         2.33        4.80                    1.10
# New Mexico            220         1.60        3.50                    0.01
# Oklahoma              171         1.21        2.47                    0.06
# Montana               148         0.98        3.30                    0.00
#
#              Alertas_Tsunami
# region
# Ca                         0
# Alaska                     0
# Texas                      0
# Hawaii                     0
# Washington                 0
# Utah                       0
# Puerto Rico                0
# New Mexico                 0
# Oklahoma                   0
# Montana                    0

# %% [markdown]
# **df_limpio['region'].isin(top_10_regiones)**: Crea un filtro booleano para evaluar qué filas pertenecen a las 10 regiones con más actividad.
#
# **.groupby('region')**: Agrupa los datos filtrados tomando como clave el nombre de cada región.
#
# **.agg(...)**: Inicia la aplicación de múltiples funciones de agregación personalizadas para cada grupo.
#
# **).sort_values(by='Total_Sismos', ascending=False)**
# : Cierra la función de agregación ".agg()." y
# ".sort_values(by='Total_Sismos', ascending=False)": Ordena la tabla resultante de forma descendente (ascending=False) tomando como base el volumen de sismos, de modo que la región con más eventos quede en el primer renglón.

# %% [markdown]
# #### **5.4 Agregaciones Temporales (Día de la Semana y Hora)**
#
# Analizamos el ritmo de ocurrencia según el día y la hora:

# %%
temporal_stats = df_limpio.groupby('dia_semana').agg(
    Total_Sismos=('mag', 'count'),
    Mag_Mediana=('mag', 'median'),
    Mag_Maxima=('mag', 'max')
).reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']) #Al aplicar .reindex(...), le obligas a presentar los días en su orden natural de la semana, de lunes a domingo.

print("="*80)
print(" DISTRIBUCIÓN SÍSMICA POR DÍA DE LA SEMANA")
print("="*80)
display(temporal_stats)
# Out:
# ================================================================================
#  DISTRIBUCIÓN SÍSMICA POR DÍA DE LA SEMANA
# ================================================================================
#             Total_Sismos  Mag_Mediana  Mag_Maxima
# dia_semana
# Monday              1460         1.50         6.4
# Tuesday             1373         1.50         6.2
# Wednesday           1498         1.50         7.5
# Thursday            1810         1.50         5.9
# Friday              1521         1.50         7.3
# Saturday            1439         1.43         6.4
# Sunday              1475         1.47         5.8

# %% [markdown]
# #### **5.5 Agregaciones Cruzadas (Interacción de Impacto y Riego)**
#
# Evaluamos la respuesta social y las alertas según la categoría de magnitud:

# %%
cruzado_impacto = df_limpio.groupby('categoria_magnitud', observed=False).agg(
    Total_Eventos=('mag', 'count'),
    Mediana_Personas_Sintieron=('felt', 'median'),
    Max_Personas_Sintieron=('felt', 'max'),
    Intensidad_Mediana_CDI=('cdi', 'median'),
    Total_Tsunamis=('tsunami', 'sum')
)
# Agrupa los sismos por su categoría de magnitud (incluyendo todas las categorías definidas aunque no tengan registros,por observed=False) y agrupa múltiples cálculos de impacto mediante .agg().

print("="*80)
print(" 🔗 5. RELACIÓN ENTRE CATEGORÍA DE MAGNITUD E IMPACTO SOCIAL")
print("="*80)
display(cruzado_impacto)
# Out:
# ================================================================================
#  🔗 5. RELACIÓN ENTRE CATEGORÍA DE MAGNITUD E IMPACTO SOCIAL
# ================================================================================
#                     Total_Eventos  Mediana_Personas_Sintieron  \
# categoria_magnitud
# Micro (<2.5)                 8774                         0.0
# Menor (2.5-4.4)              1355                         0.0
# Moderado (4.5-5.9)            434                         0.0
# Fuerte (6.0-6.9)               10                         4.5
# Mayor (>=7.0)                   3                       286.0
#
#                     Max_Personas_Sintieron  Intensidad_Mediana_CDI  \
# categoria_magnitud
# Micro (<2.5)                           122                    0.00
# Menor (2.5-4.4)                       2028                    0.00
# Moderado (4.5-5.9)                     482                    0.00
# Fuerte (6.0-6.9)                        95                    3.85
# Mayor (>=7.0)                          780                    5.40
#
#                     Total_Tsunamis
# categoria_magnitud
# Micro (<2.5)                     0
# Menor (2.5-4.4)                  0
# Moderado (4.5-5.9)               0
# Fuerte (6.0-6.9)                 0
# Mayor (>=7.0)                    0

# %% [markdown]
# #### **6. Tablas Dinámicas y Pivotaje**
#
# El objetivo de esta fase es cruzar dos o más variables para descubrir patrones ocultos que no se ven a simple vista en los resúmenes de una sola columna.

# %% [markdown]
# **6.1  MATRIZ DE RIESGO: Categoria de Magnitud vs. Alertas y Tsunamis**

# %%
pivot_alertas = pd.crosstab(
    index=df_limpio['categoria_magnitud'],
    columns=df_limpio['alert'],
    margins=True,            # Agrega los totales por fila y columna
    margins_name='Total'
)

print("="*80)
print(" 🚨 1. MATRIZ DE RIESGO: CATEGORÍA DE MAGNITUD VS. NIVEL DE ALERTA")
print("="*80)
display(pivot_alertas)
# Out:
# ================================================================================
#  🚨 1. MATRIZ DE RIESGO: CATEGORÍA DE MAGNITUD VS. NIVEL DE ALERTA
# ================================================================================
# alert               green  red  sin_alerta  yellow  Total
# categoria_magnitud
# Micro (<2.5)            0    0        8774       0   8774
# Menor (2.5-4.4)        10    0        1345       0   1355
# Moderado (4.5-5.9)     51    0         381       2    434
# Fuerte (6.0-6.9)        9    0           0       1     10
# Mayor (>=7.0)           0    2           0       1      3
# Total                  70    2       10500       4  10576

# %% [markdown]
# **pd.crosstab(categoria_magnitud, alert)**:
# Validar la coherencia de las alertas. Te permite ver exactamente cuántos sismos de cierta magnitud dispararon una alerta verde, amarilla o roja.

# %% [markdown]
# **6.2 REGIONALIZACIÓN: Top 10 Regiones vs. Categoria de Magnitud**

# %%
top_10 = df_limpio['region'].value_counts().head(10).index
df_top10 = df_limpio[df_limpio['region'].isin(top_10)]

pivot_regiones = pd.crosstab(
    index=df_top10['region'],
    columns=df_top10['categoria_magnitud'],
    normalize='index' # Muestra proporciones (porcentajes) por fila
).round(4) * 100

print("\n"+"="*80)
print("(%) DE CATEGORÍAS DE MAGNITUD EN TOP 10 REGIONES")
print("="*80)
display(pivot_regiones)
# Out:
# ================================================================================
# (%) DE CATEGORÍAS DE MAGNITUD EN TOP 10 REGIONES
# ================================================================================
# categoria_magnitud  Micro (<2.5)  Menor (2.5-4.4)  Moderado (4.5-5.9)
# region
# Alaska                     82.95            16.68                0.37
# Ca                         98.06             1.94                0.00
# Hawaii                     93.75             6.02                0.23
# Montana                    98.65             1.35                0.00
# New Mexico                 98.18             1.82                0.00
# Oklahoma                  100.00             0.00                0.00
# Puerto Rico                63.56            36.00                0.44
# Texas                      97.81             2.06                0.13
# Utah                       98.88             1.12                0.00
# Washington                 98.96             1.04                0.00

# %% [markdown]
# **pd.crosstab(region, categoria_magnitud, normalize='index'):**
#
# Comparar perfiles de riesgo entre regiones. Al usar normalize='index', conviertes los conteos en porcentajes por fila (100% por región), lo que permite responder: ¿Qué región tiene un mayor porcentaje de sismos "Fuertes"a "Micros"?.

# %% [markdown]
# **6.3 Matriz de Calor (Día de la Semana vs. Hora del Día)**

# %%
# mostrar la tabla completa
pd.set_option('display.max_columns', None)

# Crear la tabla pivote de frecuencia
pivot_temporal = pd.pivot_table(
    data=df_limpio,
    index='dia_semana',
    columns='hora_dia',
    values='mag',
    aggfunc='count',
    fill_value=0
).reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

print("\n" + "=" * 110)
print(" MAPA DE CALOR: FRECUENCIA DE SISMOS POR DÍA Y HORA DEL DÍA")
print("=" * 110)

#  Aplicar formato visual de mapa de calor
pivot_temporal_styled = pivot_temporal.style.background_gradient(
    cmap='YlOrRd',  # Escala de amarillo (bajo) a rojo (alto)
    axis=None       # Evalúa el máximo y mínimo de toda la matriz a la vez
).format("{:d}")    # Formatea como números enteros sin decimales

# Mostrar la tabla grafica
display(pivot_temporal_styled)
# Out:
# ==============================================================================================================
#  MAPA DE CALOR: FRECUENCIA DE SISMOS POR DÍA Y HORA DEL DÍA
# ==============================================================================================================
# <style type="text/css">
# #T_24a05_row0_col0, #T_24a05_row6_col12 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_24a05_row0_col1, #T_24a05_row5_col22 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_24a05_row0_col2, #T_24a05_row0_col7, #T_24a05_row0_col8, #T_24a05_row2_col9, #T_24a05_row4_col6, #T_24a05_row4_col19, #T_24a05_row4_col22 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_24a05_row0_col3, #T_24a05_row0_col23, #T_24a05_row1_col4, #T_24a05_row2_col23, #T_24a05_row5_col2 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_24a05_row0_col4, #T_24a05_row2_col1, #T_24a05_row2_col14, #T_24a05_row2_col15, #T_24a05_row5_col20 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_24a05_row0_col5, #T_24a05_row1_col19, #T_24a05_row3_col10, #T_24a05_row3_col18, #T_24a05_row3_col20, #T_24a05_row6_col15 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_24a05_row0_col6, #T_24a05_row1_col6, #T_24a05_row2_col3, #T_24a05_row2_col12, #T_24a05_row4_col0, #T_24a05_row4_col21, #T_24a05_row6_col3, #T_24a05_row6_col22, #T_24a05_row6_col23 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_24a05_row0_col9, #T_24a05_row1_col7, #T_24a05_row3_col5, #T_24a05_row4_col12 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_24a05_row0_col10, #T_24a05_row1_col15, #T_24a05_row2_col19, #T_24a05_row3_col6 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_24a05_row0_col11, #T_24a05_row0_col21, #T_24a05_row1_col16, #T_24a05_row3_col4, #T_24a05_row3_col17 {
#   background-color: #fd8a3b;
#   color: #f1f1f1;
# }
# #T_24a05_row0_col12, #T_24a05_row1_col12, #T_24a05_row2_col4, #T_24a05_row5_col23, #T_24a05_row6_col9 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_24a05_row0_col13, #T_24a05_row4_col1, #T_24a05_row4_col23, #T_24a05_row5_col12 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_24a05_row0_col14, #T_24a05_row4_col3 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_24a05_row0_col15, #T_24a05_row1_col0, #T_24a05_row1_col21, #T_24a05_row6_col6 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_24a05_row0_col16, #T_24a05_row3_col15 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_24a05_row0_col17, #T_24a05_row3_col3, #T_24a05_row3_col21 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_24a05_row0_col18, #T_24a05_row4_col18, #T_24a05_row5_col16, #T_24a05_row6_col1, #T_24a05_row6_col20 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_24a05_row0_col19, #T_24a05_row3_col23, #T_24a05_row5_col5, #T_24a05_row6_col19 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_24a05_row0_col20, #T_24a05_row3_col12, #T_24a05_row5_col7, #T_24a05_row5_col17 {
#   background-color: #febe59;
#   color: #000000;
# }
# #T_24a05_row0_col22, #T_24a05_row1_col10, #T_24a05_row4_col2, #T_24a05_row4_col20, #T_24a05_row5_col0, #T_24a05_row5_col14, #T_24a05_row6_col8 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_24a05_row1_col1, #T_24a05_row1_col18, #T_24a05_row1_col23, #T_24a05_row2_col6, #T_24a05_row2_col22, #T_24a05_row4_col14, #T_24a05_row6_col7 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_24a05_row1_col2 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_24a05_row1_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_24a05_row1_col5, #T_24a05_row4_col5, #T_24a05_row4_col16, #T_24a05_row5_col18, #T_24a05_row5_col19, #T_24a05_row6_col14, #T_24a05_row6_col17 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_24a05_row1_col8, #T_24a05_row2_col0, #T_24a05_row4_col4, #T_24a05_row5_col13, #T_24a05_row6_col21 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_24a05_row1_col9, #T_24a05_row1_col17, #T_24a05_row2_col5, #T_24a05_row2_col10 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_24a05_row1_col11, #T_24a05_row3_col2, #T_24a05_row6_col4 {
#   background-color: #fd8439;
#   color: #f1f1f1;
# }
# #T_24a05_row1_col13, #T_24a05_row5_col15 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_24a05_row1_col14, #T_24a05_row5_col10, #T_24a05_row6_col18 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_24a05_row1_col20, #T_24a05_row3_col13, #T_24a05_row6_col0, #T_24a05_row6_col2 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_24a05_row1_col22 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_24a05_row2_col2, #T_24a05_row2_col13 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_24a05_row2_col7, #T_24a05_row4_col15, #T_24a05_row4_col17, #T_24a05_row5_col9, #T_24a05_row5_col21, #T_24a05_row6_col10, #T_24a05_row6_col13 {
#   background-color: #fec15d;
#   color: #000000;
# }
# #T_24a05_row2_col8, #T_24a05_row3_col22, #T_24a05_row4_col11, #T_24a05_row5_col1, #T_24a05_row5_col6, #T_24a05_row5_col11 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_24a05_row2_col11, #T_24a05_row4_col7, #T_24a05_row5_col3, #T_24a05_row5_col8, #T_24a05_row6_col16 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_24a05_row2_col16 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_24a05_row2_col17, #T_24a05_row3_col11, #T_24a05_row4_col10 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_24a05_row2_col18 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_24a05_row2_col20, #T_24a05_row4_col8, #T_24a05_row4_col9 {
#   background-color: #fd9a42;
#   color: #000000;
# }
# #T_24a05_row2_col21 {
#   background-color: #e51e1d;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col0, #T_24a05_row3_col14, #T_24a05_row3_col16 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col1, #T_24a05_row6_col11 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col8 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col9 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_24a05_row3_col19, #T_24a05_row5_col4, #T_24a05_row6_col5 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_24a05_row4_col13 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24a05" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >hora_dia</th>
#       <th id="T_24a05_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_24a05_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_24a05_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_24a05_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_24a05_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_24a05_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_24a05_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_24a05_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_24a05_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_24a05_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_24a05_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_24a05_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_24a05_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_24a05_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_24a05_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_24a05_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_24a05_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_24a05_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_24a05_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_24a05_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_24a05_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_24a05_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_24a05_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_24a05_level0_col23" class="col_heading level0 col23" >23</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dia_semana</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th

# %% [markdown]
# **pd.set_option('display.max_columns', None):** Desactiva el límite de columnas visibles para que las 24 horas del día (0 a 23) aparezcan completas en pantalla.
#
# **pd.pivot_table(dia_semana, hora_dia):** Construir la estructura ideal para posteriormente hacer un Mapa de Calor (Heatmap), identificando horas pico de registro sísmico.
#
# **cmap='YlOrRd':** Define la paleta de colores (Yellow-Orange-Red). Las celdas con mayor conteo de sismos se tornarán rojo intenso, haciendo que los patrones temporales resalten al instante.
#
# **axis=None:** Aplica la escala de color comparando todas las celdas del cuadro entre sí, lo que te permite identificar la hora y el día pico global del dataset.
#
# **.format("{:d}"):** Asegura que la tabla muestre enteros limpios (ej. 15 en lugar de 15.0).

# %% [markdown]
# ## **7.Visualización de Datos (Data Viz).**

# %%
import matplotlib.pyplot as plt  # Librería principal para renderizar figuras y gráficos
import seaborn as sns  # Librería para gráficos estadísticos avanzados

# %% [markdown]
# **Gráfico 1: Histograma + KDE (Distribución de Magnitudes)**

# %%
print(df_limpio.columns.tolist())
# Out:
# ['mag', 'place', 'felt', 'cdi', 'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type', 'fecha_hora', 'fecha_actualizacion', 'region', 'categoria_magnitud', 'hora_dia', 'dia_semana']

# %%
# Define el estilo de fondo con cuadrícula blanca clara
plt.style.use(
    'seaborn-v0_8-whitegrid'
    if 'seaborn-v0_8-whitegrid' in plt.style.available
    else 'default'
)
plt.rcParams['font.sans-serif'] = (
    'DejaVu Sans'  # Configura la fuente tipográfica a DejaVu Sans
)
plt.rcParams['font.family'] = (
    'sans-serif'  # Establece la familia tipográfica sin serifas
)

# Construcción del Gráfico 1

fig, ax = plt.subplots(
    figsize=(8, 6)
)  # Crea la figura (fig) y su lienzo de ejes de 8x6 pulgadas

# Dibuja el histograma de distribución de magnitudes
sns.histplot(
    data=df_limpio,  # Especifica el DataFrame de origen
    x='mag',  # Asigna la columna 'mag' al eje horizontal X
    kde=True,  # Activa la curva de densidad suavizada (Kernel Density Estimation)
    bins=25,  # Divide el rango numérico en 25 barras de intervalo
    color='#d95f02',  # Aplica color naranja terracota a las barras
    ax=ax,  # Renderiza el gráfico dentro de los ejes 'ax' inicializados
)

# Configuración de textos y etiquetas
ax.set_title(
    '1. Distribución de Magnitudes (Frecuencia)', fontsize=14, fontweight='bold'
)  # Título del gráfico
ax.set_xlabel('Magnitud (mag)', fontsize=11)  # Etiqueta para el eje horizontal X
ax.set_ylabel(
    'Frecuencia de Sismos', fontsize=11
)  # Etiqueta para el eje vertical (Y)

# Marca de tendencia central (Mediana)
mediana_mag = (
    df_limpio['mag'].median()
)  # Calcula el valor de la mediana de magnitudes
ax.axvline(
    mediana_mag, color='red', linestyle='--', label=f'Mediana: {mediana_mag:.2f}'
)  # Traza una línea vertical roja punteada en la mediana
ax.legend()  # Muestra la caja de leyenda con la información de la mediana

plt.tight_layout()  # Ajusta automáticamente los márgenes de la imagen
plt.show()  # Despliega el gráfico terminado en pantalla

# %% [markdown]
# **Gráfico 2: Diagrama de Barras Horizontales (Top 10 Regiones)**

# %%
# Define el estilo de fondo con cuadrícula blanca clara
plt.style.use(
    'seaborn-v0_8-whitegrid'
    if 'seaborn-v0_8-whitegrid' in plt.style.available
    else 'default'
)
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['font.family'] = 'sans-serif'

# Construcción del Gráfico 2

fig, ax = plt.subplots(
    figsize=(9, 6)
)  #figura con dimensiones de 9x6 pulgadas

# Agregación de datos
top_regiones = (
    df_limpio['region'].value_counts().head(10)
)  # Cuenta el total por región y extrae únicamente las 10 más frecuentes

# Dibuja gráfico de barras
sns.barplot(
    x=top_regiones.values,  # Asigna la cantidad numérica de sismos al eje X
    y=top_regiones.index,  # Asigna los nombres de las regiones al eje Y (orientación horizontal)
    palette='Oranges_r',  # Aplica degradado de naranjas (la barra con más sismos será más oscura)
    hue=top_regiones.index,  # Mantiene consistencia de color mapeada por región
    legend=False,  # Oculta la leyenda auxiliar al no ser necesaria
    ax=ax,  # Asigna los ejes de renderizado
)

# Personalización del lienzo
ax.set_title(
    '2. Top 10 Regiones con Más Sismos Registrados',
    fontsize=14,
    fontweight='bold',
)  # Título principal
ax.set_xlabel('Cantidad de Eventos', fontsize=11)  # Etiqueta de frecuencia
ax.set_ylabel('Región / Ubicación', fontsize=11)  # Etiqueta de ubicación

plt.tight_layout()  # Optimiza el espacio de los bordes
plt.show()  # Muestra el gráfico en pantalla

# %% [markdown]
# **Gráfico 3: Dispersión (Magnitud vs. Profundidad)**

# %%
print(df_limpio.columns.tolist())
# Out:
# ['mag', 'place', 'felt', 'cdi', 'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type', 'fecha_hora', 'fecha_actualizacion', 'region', 'categoria_magnitud', 'hora_dia', 'dia_semana']

# %%
# Define el estilo de fondo con cuadrícula blanca clara

plt.style.use(
    'seaborn-v0_8-whitegrid'
    if 'seaborn-v0_8-whitegrid' in plt.style.available
    else 'default'
)
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['font.family'] = 'sans-serif'

# Construcción del Gráfico 3: Magnitud vs. Intensidad Mercalli

fig, ax = plt.subplots(figsize=(8, 6))

# Dibujar el gráfico
sns.scatterplot(
    data=df_limpio,
    x='mag',
    y='mmi', # tambien se puede carmbiar a y='mmi' por y='felt' o y='cdi'
    hue='tsunami',
    palette={
        0: '#2b8cbe',
        1: '#e41a1c',
    },  # 0 (No Tsunami) -> Azul | 1 (Sí Tsunami) -> Rojo
    hue_order=[0, 1],  # Garantiza que respete el orden exacto de los valores
    alpha=0.7,
    s=60,
    ax=ax,
)

# Personalización de títulos y etiquetas
ax.set_title(
    'Relación Magnitud vs. Intensidad Mercalli (Efecto Tsunami)',
    fontsize=14,
    fontweight='bold',
)
ax.set_xlabel('Magnitud (mag)', fontsize=11)
ax.set_ylabel('Intensidad Mercalli Modificada (mmi)', fontsize=11)

# Configurar leyenda explícita con los colores correctos
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles=handles,
    labels=['No (0)', 'Sí (1)'],
    title='Alerta Tsunami',
    loc='upper left',
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Si se quiere evaluar los reportes de las personas en lugar de la escala Mercalli, solo se cambia y='mmi' por y='felt' o y='cdi'.

# %% [markdown]
# **Gráfico 4: Violín (Distribución de Magnitud por Día de la Semana)**

# %%
# Define el estilo de fondo con cuadrícula blanca clara
plt.style.use(
    'seaborn-v0_8-whitegrid'
    if 'seaborn-v0_8-whitegrid' in plt.style.available
    else 'default'
)
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['font.family'] = 'sans-serif'

# Construcción del Gráfico 4 : (Día vs. Magnitud)

fig, ax = plt.subplots(figsize=(10, 5))

# Dibuja el gráfico de violín
sns.violinplot(
    data=df_limpio,
    x='dia_semana',
    y='mag',
    order=[
        'Monday',
        'Tuesday',
        'Wednesday',
        'Thursday',
        'Friday',
        'Saturday',
        'Sunday',
    ],
    palette='Set2',
    inner='quartile',  # Dibuja las líneas de cuartiles dentro del violín
    ax=ax,
)

# Personalización
ax.set_title(
    '4. Distribución y Densidad de Magnitudes por Día de la Semana',
    fontsize=14,
    fontweight='bold',
)
ax.set_xlabel('Día de la Semana', fontsize=11)
ax.set_ylabel('Magnitud (mag)', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_693/1514389529.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# ## 8. REPORTE FINAL DE HALLAZGOS (GRAFICAS)
#
# ---
#
# El presente análisis evaluó la actividad sísmica registrada por el Servicio Geológico de los Estados Unidos (**USGS**), integrando variables de magnitud, localización, temporalidad e indicadores de impacto social y alertas. El objetivo principal consistió en caracterizar los patrones de ocurrencia, evaluar el desempeño de los sistemas de alerta temprana y determinar las regiones con mayor vulnerabilidad sísmica.
#
# ---
#
# ### **Hallazgos Principales por Dimensión**
#
# #### A. Distribución de Magnitudes y Comportamiento General
# * **Dominio de Sismos Menores:** La distribución de magnitudes presenta una asimetría positiva (*skewed right*). La mediana se sitúa en rangos de **micro y menor magnitud**, cumpliendo con la Ley de Gutenberg-Richter, que establece que los eventos sísmicos de menor intensidad son exponencialmente más frecuentes que los grandes terremotos.
# * **Concentración de Masa:** La mayor densidad de registros se concentra entre magnitudes $2.5$ y $4.5$, mientras que eventos de gran magnitud ($>6.0$) representan una minoría atípica (*outliers* estadísticos).
#
# #### B. Patrones de Impacto e Intensidad (Mercalli `mmi` vs. Magnitud `mag`)
# * **Correlación Directa:** Existe una relación lineal positiva entre la magnitud del sismo y la intensidad máxima calculada en la escala de Mercalli Modificada (`mmi`).
# * **Disparación de Alertas de Tsunami:**
#   * Las alertas de tsunami (valor `1`) se activan predominantemente en sismos con **magnitudes elevadas** y **altos valores de intensidad instrumental**.
#   * No todos los sismos de alta magnitud generan alerta de tsunami, lo que confirma que el protocolo depende de factores adicionales como la ubicación marina/epicentral e hipocentral del evento.
#
# #### C. Distribución Geográfica y Concentración Regional (Top 10)
# * **Puntos Calientes (*Hotspots*):** La actividad sísmica no se distribuye de manera uniforme en el planeta. Un reducido grupo de regiones (Top 10) acumula el porcentaje mayoritario de los eventos reportados.
# * **Dominio de Zonas de Subducción / Límites de Placa:** Las regiones principales corresponden predominantemente a zonas bordeadas por el Cinturón de Fuego del Pacífico o fallas transformantes activas.
#
# #### D. Análisis Temporal (Días de la Semana y Ciclo Horario)
# * **Aleatoriedad Temporal:** El cruce cruzado (*cross-tabulation*) entre días de la semana y horas del día no muestra una concentración anómala en franjas específicas. Esto confirma la **naturaleza estocástica y no periódica** de la ocurrencia de sismos en escalas de tiempo cortas (días/horas).
# * **Consistencia del Instrumental:** Las variaciones en conteos por hora responden a fluctuaciones estadísticas normales y no a sesgos de medición en la red de sensores.
#
# ---
#
# ## 9. Conclusiones y Recomendaciones
#
# | Dimensión | Hallazgo Clave | Implicación / Recomendación |
# | :--- | :--- | :--- |
# | **Monitoreo** | Alta frecuencia de sismos de baja magnitud. | Mantener calibrada la red de sensores locales para la detección continua de micro-sismos (precursores). |
# | **Gestión del Riesgo** | Desencadenamiento de Tsunamis focalizado en magnitudes altas. | Automatizar la emisión de alertas tempranas vinculando directo el umbral de magnitud e intensidad `mmi`. |
# | **Geografía** | Gran concentración del volumen sísmico en el Top 10 de regiones. | Priorizar recursos de infraestructura y planes de prevención en estas zonas de alta densidad sísmica. |
#
# ---
#
# > **Nota para el informe:** Este apartado concluye el flujo de trabajo de análisis exploratorio de datos (EDA) para el dataset sísmico de la USGS.
